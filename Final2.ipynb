# %%
import pandas as pd
import numpy as np
import string
from tabulate import tabulate
import matplotlib.pyplot as plt
import time
df=pd.read_csv('Initial',index_col=0)
def plotgraph(df,indexc1,indexc2):
    w=0.4
    y1=df.iloc[indexc1,2:-1].tolist()
    y2=df.iloc[indexc2,2:-1].tolist()
    x=df.columns.tolist()[2:-1]
    bar1=np.arange(len(x))
    bar2=[i+w for i in bar1]
    plt.bar(bar1,y1,w,label=df['country'][indexc1])
    plt.bar(bar2,y2,w,label=df['country'][indexc2])
    plt.xticks(bar1+w/2,x)
    plt.ylabel('Values')
    plt.xlabel('Dimensions')    
    plt.legend()
    plt.title(df['country'][indexc1]+' vs '+ df['country'][indexc2])
    plt.show()
def plotgraph2(df,indexc1,indexc2,indexc3):
    w=0.2
    y1=df.iloc[indexc1,2:-1].tolist()
    y2=df.iloc[indexc2,2:-1].tolist()
    y3=df.iloc[indexc3,2:-1].tolist()
    x=df.columns.tolist()[2:-1]
    bar1=np.arange(len(x))
    bar2=[i+w for i in bar1]
    bar3=[i+w for i in bar2]
    plt.bar(bar1,y1,w,label=df['country'][indexc1])
    plt.bar(bar2,y2,w,label=df['country'][indexc2])
    plt.bar(bar3,y3,w,label=df['country'][indexc3])
    plt.xticks(bar1+w,x)
    plt.ylabel('Values')
    plt.xlabel('Dimensions')    
    plt.legend()
    plt.title((df['country'][indexc1]+' vs '+ df['country'][indexc2]+ ' vs '+ df['country'][indexc3]))    
    plt.show()

dicvalue=['POWER DISTANCE INDEX','INDIVIDUALISM VERSUS COLLECTIVISM','MASCULINITY VERSUS FEMININITY','UNCERTAINTY AVOIDANCE INDEX','LONG TERM ORIENTATION VERSUS SHORT TERM NORMATIVE ORIENTATION','INDULGENCE VERSUS RESTRAINT']
abdic=dict(zip(df.columns.tolist()[2:-1],dicvalue))
disc='Please Note: \nIf any Dimension of a country is zero, it means the data for the following dimension wasn\'t recorded in Hofstede Data Provided by GEERT HOFSTEDE in their book version 2015 12 08\n for further information you can check \'About Me and Credits.\'\n\n\n'
xyz = True
while xyz:
    credit_to_myself = 'Hofstede dimensions Viewer created by Aman Tomar'
    print(f'Welcome to {credit_to_myself}')
    print('Please Select:\n1.View Country\'s insights.\n2.Compare Countries\n3.About me and Credits \n4.Exit')
    try:        
        user_input = int(input('enter your choice:'))
        if user_input == 1:
            while True:
                user_input2_1=(input('\nPlease Enter the first letter of the counrty\'s name(a-z) you want to know about, and to see if country\'s data is available in our database: \n ').upper())
                if len(user_input2_1)>1 or user_input2_1 not in string.ascii_letters :
                    print('\nEnter Single Alphabet only')
                    continue
                elif user_input2_1.upper() not in (df['Initial'].unique().tolist()):
                    print(f'\nSorry Currently We Do Not Have Data For Any Country Starting With Alphabet: {user_input2_1}')
                    continue
                else:
                    print(tabulate(pd.DataFrame(df['country'][df['Initial']==user_input2_1.upper()]),headers=['index','country name']))
                    break

            while True:
                    try:
                        user_input2_2=int(input('\nPlease enter the index of the country u want to know about (Given on the left in numbers before country\'s name) :\n' ))
                    except ValueError:
                        print('\nEnter Index Number Given On The Left ( Example : 0 )')
                        continue
                    if user_input2_2>df.shape[0]-1:
                        print('enter correct index')
                        continue
                    else:
                        stats={'\n\nPower Distance Index':df['pdi'][user_input2_2],
                              'Indiviualism':df['idv'][user_input2_2],
                             'Uncertainty avoidance ':df['uai'][user_input2_2],
                              'Masculinity vs. femininity':df['mas'][user_input2_2],
                              'Long-term orientation vs. short-term orientation':df['ltowvs'][user_input2_2],
                              'Indulgence vs. restraint':df['ivr'][user_input2_2]}
                        print(f'\nHofstede Dimensions For {(df.country[user_input2_2])} are : \n')
                        headers=['Dimensions','Values']
                        print(tabulate(stats.items(), headers = headers))
                        print (disc)
                        break


        elif user_input == 2:
            while True:
                try:   
                    user_input_3_0=int(input('how many countries do you want to compare? 2 or 3:\n' ))
                    if user_input_3_0==2:
                        while True:
                                user_input3_1=(input('\nPlease Enter the first letter of the counrty\'s name(a-z) you want to know about, and to see if country\'s data is available in our database: \n ').upper())
                                if len(user_input3_1)>1 or user_input3_1 not in string.ascii_letters :
                                    print('\nEnter Single Alphabet only')
                                    continue
                                elif user_input3_1.upper() not in (df['Initial'].unique().tolist()):
                                    print(f'\nSorry Currently We Do Not Have Data For Any Country Starting With Alphabet: {user_input3_1}')
                                    continue
                                else:
                                    print(tabulate(pd.DataFrame(df['country'][df['Initial']==user_input3_1.upper()]),headers=['index','country name']))
                                try:
                                    indexc1=int(input('\nPlease enter the index of the country u want to know about (Given on the left in numbers before country\'s name) :\n' ))
                                except ValueError:
                                    print('\nEnter Index Number Given On The Left ( Example : 0 )')
                                    continue
                                if indexc1>df.shape[0]-1:
                                    print('Enter The Correct Index Number')
                                    continue
                                else:
                                    break


                        while True:
                            user_input3_2=(input('\nPlease Enter the first letter of the counrty\'s name(a-z) you want to know about, and to see if country\'s data is available in our database: \n ').upper())
                            if len(user_input3_2)>1 or user_input3_2 not in string.ascii_letters :
                                print('\nEnter Single Alphabet only')
                                continue
                            elif user_input3_2.upper() not in (df['Initial'].unique().tolist()):
                                print(f'\nSorry Currently We Do Not Have Data For Any Country Starting With Alphabet: {user_input3_2}')
                                continue
                            else:
                                print(tabulate(pd.DataFrame(df['country'][df['Initial']==user_input3_2.upper()]),headers=['index','country name']))
                            try:
                                indexc2=int(input('\nPlease enter the index of the country u want to know about (Given on the left in numbers before country\'s name) :\n' ))
                            except ValueError:
                                print('\nEnter Index Number Given On The Left ( Example : 0 )')
                                continue
                            if indexc2>df.shape[0]-1:
                                print('Enter The Correct Index Number')
                                continue

                            else:
                                print (abdic)
                                plotgraph(df,indexc1,indexc2)
                                print (disc)
                                break
            #if user input 3
                    elif user_input_3_0==3:
                        while True:
                                user_input3_3=(input('\nPlease Enter the first letter of the counrty\'s name(a-z) you want to know about, and to see if country\'s data is available in our database: \n ').upper())
                                if len(user_input3_3)>1 or user_input3_3 not in string.ascii_letters :
                                    print('\nEnter Single Alphabet only')
                                    continue
                                elif user_input3_3.upper() not in (df['Initial'].unique().tolist()):
                                    print(f'\nSorry Currently We Do Not Have Data For Any Country Starting With Alphabet: {user_input3_3}')
                                    continue
                                else:
                                    print(tabulate(pd.DataFrame(df['country'][df['Initial']==user_input3_3.upper()]),headers=['index','country name']))
                                try:
                                    indexc1=int(input('\nPlease enter the index of the country u want to know about (Given on the left in numbers before country\'s name) :\n' ))
                                except ValueError:
                                    print('\nEnter Index Number Given On The Left ( Example : 0 )')
                                    continue
                                if indexc1>df.shape[0]-1:
                                    print('Enter The Correct Index Number')
                                    continue

                                else:
                                    break


                        while True:
                            user_input3_4=(input('\nPlease Enter the first letter of the counrty\'s name(a-z) you want to know about, and to see if country\'s data is available in our database: \n ').upper())
                            if len(user_input3_4)>1 or user_input3_4 not in string.ascii_letters :
                                print('\nEnter Single Alphabet only')
                                continue
                            elif user_input3_4.upper() not in (df['Initial'].unique().tolist()):
                                print(f'\nSorry Currently We Do Not Have Data For Any Country Starting With Alphabet: {user_input3_4}')
                                continue
                            else:
                                print(tabulate(pd.DataFrame(df['country'][df['Initial']==user_input3_4.upper()]),headers=['index','country name']))
                            try:
                                indexc2=int(input('\nPlease enter the index of the country u want to know about (Given on the left in numbers before country\'s name) :\n' ))
                            except ValueError:
                                print('\nEnter Index Number Given On The Left ( Example : 0 )')
                                continue
                            if indexc2>df.shape[0]-1:
                                print('Enter The Correct Index Number')
                                continue

                            else:
                                break

                        while True:
                            user_input3_5=(input('\nPlease Enter the first letter of the counrty\'s name(a-z) you want to know about, and to see if country\'s data is available in our database: \n ').upper())
                            if len(user_input3_5)>1 or user_input3_5 not in string.ascii_letters :
                                print('\nEnter Single Alphabet only')
                                continue
                            elif user_input3_5.upper() not in (df['Initial'].unique().tolist()):
                                print(f'\nSorry Currently We Do Not Have Data For Any Country Starting With Alphabet: {user_input3_5}')
                                continue
                            else:
                                print(tabulate(pd.DataFrame(df['country'][df['Initial']==user_input3_5.upper()]),headers=['index','country name']))
                            try:
                                indexc3=int(input('\nPlease enter the index of the country u want to know about (Given on the left in numbers before country\'s name) :\n' ))
                            except ValueError:
                                print('\nEnter Index Number Given On The Left ( Example : 0 )')
                                continue
                            if indexc3>df.shape[0]-1:
                                print('Enter The Correct Index Number')
                                continue
                            else:
                                print(abdic)
                                plotgraph2(df,indexc1,indexc2,indexc3)
                                print(disc)
                                break
                   #if user enters more than 2             
                    else:
                        print('Enter either 2 or 3')
                        continue




                    break

                except ValueError:
                    print('Enter either 2 or 3')


        elif user_input == 3:
            print('Hi I am Aman Tomar,resident of India.I completed my Masters In Business Administration from Sharda University(Greater Noida, Uttar Pradesh, India). I started learning python in year 2021, using various Youtube Resources(primarily Freecodecamp), while learning i enjoyed playing around with random datasets, which further ended with me joining Data Analyst Course on Udemy.After finishing my course i practiced on various other platforms including Linkedin Learning,Kaggle and Cognitiveai. Currently I\'m working to improve Tableau,Mysql and Excel Spreadsheet skills.  I have always loved to explore how different societies and cultures works,this encouraged me to do my first Python Project on Hofstede Insights.The data for this project was collected from Geert Hofstede website: https://geerthofstede.com/research-and-vsm/dimension-data-matrix/, which also includes further information on Hofstede Insights\n\n\n')
        elif user_input == 4:
            print('Thank You Visiting, Send me reviews at aman22tomar@gmail.com')
            time.sleep(10)
            xyz = False

        else:
            print(
            '\n \n Enter A Number In Range (1-4) \n \n' )
    except ValueError:
        print('\n\nEnter a Number Only(1-4)')
# Out:
# Welcome to Hofstede dimensions Viewer created by Aman Tomar
# Please Select:
# 1.View Country's insights.
# 2.Compare Countries
# 3.About me and Credits
# 4.Exit
# enter your choice:1
#
# Please Enter the first letter of the counrty's name(a-z) you want to know about, and to see if country's data is available in our database:
#  f
#   index  country name
# -------  --------------
#      36  Finland
#      37  France
#
# Please enter the index of the country u want to know about (Given on the left in numbers before country's name) :
# 37
#
# Hofstede Dimensions For France are :
#
# Dimensions                                          Values
# ------------------------------------------------  --------
# Power Distance Index                                    68
# Indiviualism                                            71
# Uncertainty avoidance                                   86
# Masculinity vs. femininity                              43
# ...
